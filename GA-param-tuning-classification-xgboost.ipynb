# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from random import randint,uniform
from sklearn.model_selection import train_test_split
from time import time
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
popSize = 50
eliteSize = 0.1
mutation_rate = 0.2
nGeneration = 100

# %%
paramList = ['depth','max_bin','eta','gamma','min_child_weight','colsample_bytree','subsample',\
            'fitness']
population = pd.DataFrame(np.zeros(shape=(popSize,len(paramList))),columns=paramList)
population.depth = [randint(6,15) for p in range(0,popSize)]
population.max_bin = [randint(80,150) for p in range(0,popSize)]
population.eta = [uniform(0.1,1) for p in range(0,popSize)]
population.gamma = [uniform(0.01,0.03) for p in range(0,popSize)]
population.min_child_weight = [randint(1,20) for p in range(0,popSize)]
population.colsample_bytree = [uniform(0.7,0.95) for p in range(0,popSize)]
population.subsample = [uniform(0.7,0.95) for p in range(0,popSize)]
population.fitness = [uniform(0,0) for p in range(0,popSize)]

# %%
population.head()
# Out:
#    depth  max_bin       eta     gamma  min_child_weight  colsample_bytree  \
# 0     15       90  0.234493  0.020332                10          0.806451
# 1     11      148  0.721107  0.014304                13          0.701083
# 2     15      145  0.834003  0.017085                15          0.828568
# 3     14      129  0.600723  0.022222                 3          0.862359
# 4     13      101  0.875595  0.029728                 3          0.913291
#
#    subsample  fitness
# 0   0.787508      0.0
# 1   0.837215      0.0
# 2   0.898657      0.0
# 3   0.816103      0.0
# 4   0.768916      0.0

# %%
population.shape
# Out:
# (50, 8)

# %%
def createNewPopulation(population,eliteSize=eliteSize,mutation_rate=mutation_rate,popSize=popSize):
    population.sort_values(['fitness'],ascending=False,inplace=True)
    population.reset_index(drop=True,inplace=True)
    popSize = population.shape[0]
    nElite = int(round(eliteSize*popSize))
    
    new_population = population.copy(deep=True)
    for i in range(nElite,popSize):
        # create father and mother
        p1 = randint(0,int(popSize/2))
        p2 = randint(0,int(popSize/2))
        
        for attr in list(new_population.columns.values):
            if(uniform(0,1)>0.5):
                new_population.loc[i,attr] = population.loc[p1,attr]
            else:
                new_population.loc[i,attr] = population.loc[p2,attr]
                
            if(uniform(0,1)<mutation_rate):
                attr = list(new_population.columns.values)[randint(0,new_population.shape[1]-2)]
                if(attr=='depth'):
                    new_population.loc[i,attr] = max(3,new_population.loc[i,attr]+randint(-2,2))
                elif(attr=='max_bin'):
                    new_population.loc[i,attr] = max(70,new_population.loc[i,attr]+randint(-20,20))
                elif(attr=='eta'):
                    new_population.loc[i,attr] = min(max(0.1,new_population.loc[i,attr]+uniform(-0.05,0.05)),1)
                elif(attr=='gamma'):
                    new_population.loc[i,attr] = max(0.1,new_population.loc[i,attr]+uniform(-0.005,0.005))
                elif(attr=='min_child_weight'):
                    new_population.loc[i,attr] = max(0,new_population.loc[i,attr]+randint(-2,2))
                elif(attr=='colsample_bytree'):
                    new_population.loc[i,attr] = min(max(0.6,new_population.loc[i,attr]+uniform(-0.05,0.05)),1)
                elif(attr=='subsample'):
                    new_population.loc[i,attr] = min(max(0.6,new_population.loc[i,attr]+uniform(-0.05,0.05)),1)
    return new_population

# %%
def testInstance(population,i,dtrain):
    params = {
        'objective':'binary:logitraw',
        'tree_method':'hist',
        'eta':population.eta[i],
        'max_depth':population.depth[i],
        'subsample':population.subsample[i],
        'colsample_bytree':population.colsample_bytree[i],
        'max_bin':population.max_bin[i],
        'gamma':population.gamma[i],
        'min_child_weight':population.min_child_weight[i],
        'silent':1,
        'seed':401,
    }
    history = xgb.cv(
        params,
        dtrain,
        num_boost_round = 30,
        nfold=3,
        verbose_eval = False,
        metrics = 'auc'
        )
    return history['test-auc-mean'].iloc[-1]

# %%
def printResult(filename,population,i,generation):
    f1 = open(filename,'a')
    f1.write('Generation %d Best fitness %f\n' % (generation,population.fitness[i]))
    f1.write('"eta":%f\n' % population.eta[i])
    f1.write('"max_depth":%f\n' %population.depth[i])
    f1.write('"subsample":%f\n' %population.subsample[i])
    f1.write('"colsample_bytree":%f\n' %population.colsample_bytree[i])
    f1.write('"min_child_weight":%f\n' %population.min_child_weight[i])
    f1.write('"max_bin":%f\n' %population.max_bin[i])
    f1.close()

# %%
def evolve(dtrain,nGeneration=nGeneration,popSize=popSize,eliteSize=eliteSize,population=population):
    for gen in range(nGeneration):
        print('Generation %d\n' %gen)
        population = createNewPopulation(population)
        nElite = int(round(eliteSize*popSize))
        for i in range(nElite,popSize):
            print('testing instance %d' %i)
            population.loc[i,'fitness'] = testInstance(population,i,dtrain)
            print('--Fitness %f \n' %population.fitness[i])
        population.sort_values(['fitness'],ascending=False,inplace=True)
        population.reset_index(drop=True,inplace=True)
        printResult('xgb_result.txt',population,0,gen)
        print('Generation %d Best fitness (5-fold mae cv): %f' %(gen,population.fitness[0]))

# %%
data = pd.read_csv('titanic_data.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
for col in data.columns.values:
    print(col,sum(data[col].isnull()))
# Out:
# PassengerId 0
# Survived 0
# Pclass 0
# Name 0
# Sex 0
# Age 177
# SibSp 0
# Parch 0
# Ticket 0
# Fare 0
# Cabin 687
# Embarked 2

# %%
np.mean(data.Age)
# Out:
# 29.69911764705882

# %%
data.Age.fillna(np.mean(data.Age),inplace=True)

# %%
data.Cabin.fillna(0,inplace=True)

# %%
data.Embarked.fillna(0,inplace=True)

# %%
for col in data.columns.values:
    print(col,sum(data[col].isnull()))
# Out:
# PassengerId 0
# Survived 0
# Pclass 0
# Name 0
# Sex 0
# Age 0
# SibSp 0
# Parch 0
# Ticket 0
# Fare 0
# Cabin 0
# Embarked 0

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500     0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250     0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500     0        S

# %%
def zero_to_string(data):
    if data == 0:
        return '0'
    else:
        return data

# %%
sex_encoder = LabelEncoder()
newSex = sex_encoder.fit_transform(data.Sex)
cabin_encoder = LabelEncoder()
newCabin = cabin_encoder.fit_transform(data.Cabin.apply(zero_to_string))
embarked_encoder = LabelEncoder()
newEmbarked = embarked_encoder.fit_transform(data.Embarked.apply(zero_to_string))

# %%
sex = pd.Series(newSex,name='Sex')
cabin = pd.Series(newCabin,name='Cabin')
embarked = pd.Series(newEmbarked,name='Embarked')

# %%
full_data = pd.concat([data.drop(['PassengerId','Name','Sex','Ticket','Cabin','Embarked'],axis=1),\
                      sex,cabin,embarked],axis=1)

# %%
full_data.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex  Cabin  Embarked
# 0         0       3  22.0      1      0   7.2500    1      0         3
# 1         1       1  38.0      1      0  71.2833    0     82         1
# 2         1       3  26.0      0      0   7.9250    0      0         3
# 3         1       1  35.0      1      0  53.1000    0     56         3
# 4         0       3  35.0      0      0   8.0500    1      0         3

# %%
xtrain,xtest,ytrain,ytest = train_test_split(full_data.drop('Survived',axis=1),full_data.Survived,test_size=0.1,random_state=401)

# %%
dtrain = xgb.DMatrix(xtrain,ytrain)
dtest = xgb.DMatrix(xtest,ytest)

# %%
evolve(dtrain)
# Out:
# Generation 0
#
# testing instance 5
# --Fitness 0.845142
#
# testing instance 6
# --Fitness 0.858937
#
# testing instance 7
# --Fitness 0.840686
#
# testing instance 8
# --Fitness 0.844962
#
# testing instance 9
# --Fitness 0.845631
#
# testing instance 10
# --Fitness 0.855334
#
# testing instance 11
# --Fitness 0.839391
#
# testing instance 12
# --Fitness 0.855199
#
# testing instance 13
# --Fitness 0.847989
#
# testing instance 14
# --Fitness 0.847010
#
# testing instance 15
# --Fitness 0.842017
#
# testing instance 16
# --Fitness 0.863658
#
# testing instance 17
# --Fitness 0.854683
#
# testing instance 18
# --Fitness 0.855369
#
# testing instance 19
# --Fitness 0.846708
#
# testing instance 20
# --Fitness 0.852344
#
# testing instance 21
# --Fitness 0.863649
#
# testing instance 22
# --Fitness 0.856990
#
# testing instance 23
# --Fitness 0.854650
#
# testing instance 24
# --Fitness 0.842955
#
# testing instance 25
# --Fitness 0.847169
#
# testing instance 26
# --Fitness 0.844894
#
# testing instance 27
# --Fitness 0.867087
#
# testing instance 28
# --Fitness 0.853688
#
# testing instance 29
# --Fitness 0.854577
#
# testing instance 30
# --Fitness 0.861962
#
# testing instance 31
# --Fitness 0.843276
#
# testing instance 32
# --Fitness 0.850003
#
# testing instance 33
# --Fitness 0.844566
#
# testing instance 34
# --Fitness 0.849495
#
# testing instance 35
# --Fitness 0.854743
#
# testing instance 36
# --Fitness 0.839668
#
# testing instance 37
# --Fitness 0.840950
#
# testing instance 38
# --Fitness 0.855548
#
# testing instance 39
# --Fitness 0.852145
#
# testing instance 40
# --Fitness 0.851368
#
# testing instance 41
# --Fitness 0.857818
#
# testing instance 42
# --Fitness 0.838840
#
# testing instance 43
# --Fitness 0.845913
#
# testing instance 44
# --Fitness 0.851998
#
# testing instance 45
# --Fitness 0.858054
#
# testing instance 46
# --Fitness 0.846593
#
# testing instance 47
# --Fitness 0.862313
#
# testing instance 48
# --Fitness 0.856969
#
# testing instance 49
# --Fitness 0.849401
#
# Generation 0 Best fitness (5-fold mae cv): 0.867087
# Generation 1
#
# testing instance 5
# --Fitness 0.851335
#
# testing instance 6
# --Fitness 0.847985
#
# testing instance 7
# --Fitness 0.852893
#
# testing instance 8
# --Fitness 0.850515
#
# testing instance 9
# --Fitness 0.852286
#
# testing instance 10
# --Fitness 0.855639
#
# testing instance 11
# --Fitness 0.857687
#
# testing instance 12
# --Fitness 0.846577
#
# testing instance 13
# --Fitness 0.852644
#
# testing instance 14
# --Fitness 0.858918
#
# testing instance 15
# --Fitness 0.855729
#
# testing instance 16
# --Fitness 0.842907
#
# testing instance 17
# --Fitness 0.849564
#
# testing instance 18
# --Fitness 0.858036
#
# testing instance 19
# --Fitness 0.858833
#
# testing instance 20
# --Fitness 0.855666
#
# testing instance 21
# --Fitness 0.850874
#
# testing instance 22
# --Fitness 0.854247
#
# testing instance 23
# --Fitness 0.852203
#
# testing instance 24
# --Fitness 0.861410
#
# testing instance 25
# --Fitness 0.858653
#
# testing instance 26
# --Fitness 0.845608
#
# testing instance 27
# --Fitness 0.851210
#
# testing instance 28
# --Fitness 0.848161
#
# testing instance 29
# --Fitness 0.866069
#
# testing instance 30
# --Fitness 0.863065
#
# testing instance 31
# --Fitness 0.850446
#
# testing instance 32
# --Fitness 0.849381
#
# testing instance 33
# --Fitness 0.851292
#
# testing instance 34
# --Fitness 0.846322
#
# testing instance 35
# --Fitness 0.849482
#
# testing instance 36
# --Fitness 0.856969
#
# testing instance 37
# --Fitness 0.849929
#
# testing instance 38
# --Fitness 0.857077
#
# testing instance 39
# --Fitness 0.851315
#
# testing instance 40
# --Fitness 0.860906
#
# testing instance 41
# --Fitness 0.856362
#
# testing instance 42
# --Fitness 0.857081
#
# testing instance 43
# --Fitness 0.852255
#
# testing instance 44
# --Fitness 0.867382
#
# testing instance 45
# --Fitness 0.856112
#
# testing instance 46
# --Fitness 0.859213
#
# testing instance 47
# --Fitness 0.855094
#
# testing instance 48
# --Fitness 0.843743
#
# testing instance 49
# --Fitness 0.860282
#
# Generation 1 Best fitness (5-fold mae cv): 0.867382
# Generation 2
#
# testing instance 5
# --Fitness 0.858401
#
# testing instance 6
# --Fitness 0.850010
#
# testing instance 7
# --Fitness 0.849325
#
# testing instance 8
# --Fitness 0.850760
#
# testing instance 9
# --Fitness 0.856540
#
# testing instance 10
# --Fitness 0.868120
#
# testing instance 11
# --Fitness 0.848106
#
# testing instance 12
# --Fitness 0.860794
#
# testing instance 13
# --Fitness 0.867087
#
# testing instance 14
# --Fitness 0.855737
#
# testing instance 15
# --Fitness 0.852603
#
# testing instance 16
# --Fitness 0.847623
#
# testing instance 17
# --Fitness 0.860548
#
# testing instance 18
# --Fitness 0.853932
#
# testing instance 19
# --Fitness 0.847827
#
# testing instance 20
# --Fitness 0.854945
#
# testing instance 21
# --Fitness 0.858720
#
# testing instance 22
# --Fitness 0.857974
#
# testing instance 23
# --Fitness 0.852547
#
# testing instance 24
# --Fitness 0.861625
#
# testing instance 25
# --Fitness 0.852613
#
# testing instance 26
# --Fitness 0.852570
#
# testing instance 27
# --Fitness 0.863237
#
# testing instance 28
# --Fitness 0.857520
#
# testing instance 29
# --Fitness 0.857117
#
# testing instance 30
# --Fitness 0.849669
#
# testing instance 31
# --Fitness 0.860557
#
# testing instance 32
# --Fitness 0.847779
#
# testing instance 33
# --Fitness 0.855451
#
# testing instance 34
# --Fitness 0.856934
#
# testing instance 35
# --Fitness 0.859554
#
# testing instance 36
# --Fitness 0.851656
#
# testing instance 37
# --Fitness 0.859048
#
# testing instance 38
# --Fitness 0.846850
#
# testing instance 39
# --Fitness 0.864049
#
# testing instance 40
# --Fitness 0.861739
#
# testing instance 41
# --Fitness 0.859259
#
# testing instance 42
# --Fitness 0.846151
#
# testing instance 43
# --Fitness 0.860906
#
# testing instance 44
# --Fitness 0.862143
#
# testing instance 45
# --Fitness 0.856656
#
# testing instance 46
# --Fitness 0.851516
#
# testing instance 47
# --Fitness 0.853485
#
# testing instance 48
# --Fitness 0.856123
#
# testing instance 49
# --Fitness 0.853773
#
# Generation 2 Best fitness (5-fold mae cv): 0.868120
# Generation 3
#
# testing instance 5
# --Fitness 0.862143
#
# testing instance 6
# --Fitness 0.861593
#
# testing instance 7
# --Fitness 0.862143
#
# testing instance 8
# --Fitness 0.846831
#
# testing instance 9
# --Fitness 0.864023
#
# testing instance 10
# --Fitness 0.853667
#
# testing instance 11
# --Fitness 0.863460
#
# testing instance 12
# --Fitness 0.861625
#
# testing instance 13
# --Fitness 0.858609
#
# testing instance 14
# --Fitness 0.862932
#
# testing instance 15
# --Fitness 0.864870
#
# testing instance 16
# --Fitness 0.846116
#
# testing instance 17
# --Fitness 0.856215
#
# testing instance 18
# --Fitness 0.851170
#
# testing instance 19
# --Fitness 0.858913
#
# testing instance 20
# --Fitness 0.863706
#
# testing instance 21
# --Fitness 0.862120
#
# testing instance 22
# --Fitness 0.860365
#
# testing instance 23
# --Fitness 0.857036
#
# testing instance 24
# --Fitness 0.863126
#
# testing instance 25
# --Fitness 0.857993
#
# testing instance 26
# --Fitness 0.858575
#
# testing instance 27
# --Fitness 0.862592
#
# testing instance 28
# --Fitness 0.859635
#
# testing instance 29
# --Fitness 0.856621
#
# testing instance 30
# --Fitness 0.856864
#
# testing instance 31
# --Fitness 0.848293
#
# testing instance 32
# --Fitness 0.863916
#
# testing instance 33
# --Fitness 0.863049
#
# testing instance 34
# --Fitness 0.856709
#
# testing instance 35
# --Fitness 0.855554
#
# testing instance 36
# --Fitness 0.849657
#
# testing instance 37
# --Fitness 0.854313
#
# testing instance 38
# --Fitness 0.858986
#
# testing instance 39
# --Fitness 0.862517
#
# testing instance 40
# --Fitness 0.862414
#
# testing instance 41
# --Fitness 0.859024
#
# testing instance 42
# --Fitness 0.863374
#
# testing instance 43
# --Fitness 0.852504
#
# testing instance 44
# --Fitness 0.865032
#
# testing instance 45
# --Fitness 0.859437
#
# testing instance 46
# --Fitness 0.849032
#
# testing instance 47
# --Fitness 0.856621
#
# testing instance 48
# --Fitness 0.862644
#
# testing instance 49
# --Fitness 0.865731
#
# Generation 3 Best fitness (5-fold mae cv): 0.868120
# Generation 4
#
# testing instance 5
# --Fitness 0.858089
#
# testing instance 6
# --Fitness 0.851702
#
# testing instance 7
# --Fitness 0.853016
#
# testing instance 8
# --Fitness 0.849353
#
# testing instance 9
# --Fitness 0.851759
#
# testing instance 10
# --Fitness 0.865958
#
# testing instance 11
# --Fitness 0.864516
#
# testing instance 12
# --Fitness 0.867087
#
# testing instance 13
# --Fitness 0.859274
#
# testing instance 14
# --Fitness 0.853482
#
# testing instance 15
# --Fitness 0.858911
#
# testing instance 16
# --Fitness 0.857814
#
# testing instance 17
# --Fitness 0.856509
#
# testing instance 18
# --Fitness 0.852533
#
# testing instance 19
# --Fitness 0.863788
#
# testing instance 20
# --Fitness 0.870920
# testing instance 21
# --Fitness 0.863970
#
# testing instance 22
# --Fitness 0.860035
#
# testing instance 23
# --Fitness 0.854575
#
# testing instance 24
# --Fitness 0.867087
#
# testing instance 25
# --Fitness 0.863190
#
# testing instance 26
# --Fitness 0.865032
#
# testing instance 27
# --Fitness 0.863049
#
# testing instance 28
# --Fitness 0.860480
#
# testing instance 29
# --Fitness 0.865747
#
# testing instance 30
# --Fitness 0.862853
#
# testing instance 31
# --Fitness 0.851196
#
# testing instance 32
# --Fitness 0.863928
#
# testing instance 33
# --Fitness 0.862143
#
# testing instance 34
# --Fitness 0.870082
#
# testing instance 35
# --Fitness 0.851222
#
# testing instance 36
# --Fitness 0.858751
#
# testing instance 37
# --Fitness 0.861509
#
# testing instance 38
# --Fitness 0.857017
#
# testing instance 39
# --Fitness 0.856353
#
# testing instance 40
# --Fitness 0.852727
#
# testing instance 41
# --Fitness 0.860115
#
# testing instance 42
# --Fitness 0.863347
#
# testing instance 43
# --Fitness 0.856584
#
# testing instance 44
# --Fitness 0.859048
#
# testing instance 45
# --Fitness 0.854524
#
# testing instance 46
# --Fitness 0.856422
#
# testing instance 47
# --Fitness 0.863398
#
# testing instance 48
# --Fitness 0.859740
#
# testing instance 49
# --Fitness 0.863781
#
# Generation 4 Best fitness (5-fold mae cv): 0.870920
# Generation 5
#
# testing instance 5
# --Fitness 0.867087
#
# testing instance 6
# --Fitness 0.863599
#
# testing instance 7
# --Fitness 0.867087
#
# testing instance 8
# --Fitness 0.860210
#
# testing instance 9
# --Fitness 0.864635
#
# testing instance 10
# --Fitness 0.863928
#
# testing instance 11
# --Fitness 0.856152
#
# testing instance 12
# --Fitness 0.867087
#
# testing instance 13
# --Fitness 0.867087
#
# testing instance 14
# --Fitness 0.867087
#
# testing instance 15
# --Fitness 0.858652
#
# testing instance 16
# --Fitness 0.862251
#
# testing instance 17
# --Fitness 0.858929
#
# testing instance 18
# --Fitness 0.861321
#
# testing instance 19
# --Fitness 0.860659
#
# testing instance 20
# --Fitness 0.865958
#
# testing instance 21
# --Fitness 0.860115
#
# testing instance 22
# --Fitness 0.860553
#
# testing instance 23
# --Fitness 0.861426
#
# testing instance 24
# --Fitness 0.850105
#
# testing instance 25
# --Fitness 0.865463
#
# testing instance 26
# --Fitness 0.847950
#
# testing instance 27
# --Fitness 0.858846
#
# testing instance 28
# --Fitness 0.862262
#
# testing instance 29
# --Fitness 0.860321
#
# testing instance 30
# --Fitness 0.868978
#
# testing instance 31
# --Fitness 0.853787
#
# testing instance 32
# --Fitness 0.867087
#
# testing instance 33
# --Fitness 0.862003
#
# testing instance 34
# --Fitness 0.863568
#
# testing instance 35
# --Fitness 0.854317
#
# testing instance 36
# --Fitness 0.867382
#
# testing instance 37
# --Fitness 0.866653
#
# testing instance 38
# --Fitness 0.867087
#
# testing instance 39
# --Fitness 0.865783
#
# testing instance 40
# --Fitness 0.858412
#
# testing instance 41
# --Fitness 0.865169
#
# testing instance 42
# --Fitness 0.854320
#
# testing instance 43
# --Fitness 0.867546
#
# testing instance 44
# --Fitness 0.865776
#
# testing instance 45
# --Fitness 0.863492
#
# testing instance 46
# --Fitness 0.867087
#
# testing instance 47
# --Fitness 0.856470
#
# testing instance 48
# --Fitness 0.859907
#
# testing instance 49
# --Fitness 0.861682
#
# Generation 5 Best fitness (5-fold mae cv): 0.870920
# Generation 6
#
# testing instance 5
# --Fitness 0.867087
#
# testing instance 6
# --Fitness 0.856461
#
# testing instance 7
# --Fitness 0.860390
#
# testing instance 8
# --Fitness 0.862662
#
# testing instance 9
# --Fitness 0.859041
#
# testing instance 10
# --Fitness 0.865958
#
# testing instance 11
# --Fitness 0.865940
#
# testing instance 12
# --Fitness 0.866352
#
# testing instance 13
# --Fitness 0.865361
#
# testing instance 14
# --Fitness 0.869722
#
# testing instance 15
# --Fitness 0.867087
#
# testing instance 16
# --Fitness 0.864548
#
# testing instance 17
# --Fitness 0.865169
#
# testing instance 18
# --Fitness 0.859812
#
# testing instance 19
# --Fitness 0.866653
#
# testing instance 20
# --Fitness 0.870710
#
# testing instance 21
# --Fitness 0.868066
#
# testing instance 22
# --Fitness 0.870465
#
# testing instance 23
# --Fitness 0.862354
#
# testing instance 24
# --Fitness 0.867087
#
# testing instance 25
# --Fitness 0.863781
#
# testing instance 26
# --Fitness 0.867087
#
# testing instance 27
# --Fitness 0.867382
#
# testing instance 28
# --Fitness 0.859745
#
# testing instance 29
# --Fitness 0.865327
#
# testing instance 30
# --Fitness 0.867087
#
# testing instance 31
# --Fitness 0.865948
#
# testing instance 32
# --Fitness 0.866216
#
# testing instance 33
# --Fitness 0.867087
#
# testing instance 34
# --Fitness 0.859395
#
# testing instance 35
# --Fitness 0.863338
#
# testing instance 36
# --Fitness 0.867087
#
# testing instance 37
# --Fitness 0.866787
#
# testing instance 38
# --Fitness 0.864626
#
# testing instance 39
# --Fitness 0.858496
#
# testing instance 40
# --Fitness 0.860704
#
# testing instance 41
# --Fitness 0.866678
#
# testing instance 42
# --Fitness 0.860321
#
# testing instance 43
# --Fitness 0.866653
#
# testing instance 44
# --Fitness 0.859327
#
# testing instance 45
# --Fitness 0.862972
#
# testing instance 46
# --Fitness 0.861070
#
# testing instance 47
# --Fitness 0.865911
#
# testing instance 48
# --Fitness 0.866653
#
# testing instance 49
# --Fitness 0.863535
#
# Generation 6 Best fitness (5-fold mae cv): 0.870920
# Generation 7
#
# testing instance 5
# --Fitness 0.862466
#
# testing instance 6
# --Fitness 0.864438
#
# testing instance 7
# --Fitness 0.863306
#
# testing instance 8
# --Fitness 0.865042
#
# testing instance 9
# --Fitness 0.867546
#
# testing instance 10
# --Fitness 0.861609
#
# testing instance 11
# --Fitness 0.859053
#
# testing instance 12
# --Fitness 0.866653
#
# testing instance 13
# --Fitness 0.858605
#
# testing instance 14
# --Fitness 0.867674
#
# testing instance 15
# --Fitness 0.855622
#
# testing instance 16
# --Fitness 0.864143
#
# testing instance 17
# --Fitness 0.867087
#
# testing instance 18
# --Fitness 0.860144
#
# testing instance 19
# --Fitness 0.861109
#
# testing instance 20
# --Fitness 0.866678
#
# testing instance 21
# --Fitness 0.863178
#
# testing instance 22
# --Fitness 0.867546
#
# testing instance 23
# --Fitness 0.867087
#
# testing instance 24
# --Fitness 0.854957
#
# testing instance 25
# --Fitness 0.869209
#
# testing instance 26
# --Fitness 0.859904
#
# testing instance 27
# --Fitness 0.861530
#
# testing instance 28
# --Fitness 0.865186
#
# testing instance 29
# --Fitness 0.867546
#
# testing instance 30
# --Fitness 0.864590
#
# testing instance 31
# --Fitness 0.868120
#
# testing instance 32
# --Fitness 0.865215
#
# testing instance 33
# --Fitness 0.863035
#
# testing instance 34
# --Fitness 0.863345
#
# testing instance 35
# --Fitness 0.862903
#
# testing instance 36
# --Fitness 0.862097
#
# testing instance 37
# --Fitness 0.867087
#
# testing instance 38
# --Fitness 0.870710
#
# testing instance 39
# --Fitness 0.866364
#
# testing instance 40
# --Fitness 0.862861
#
# testing instance 41
# --Fitness 0.864146
#
# testing instance 42
# --Fitness 0.859938
#
# testing instance 43
# --Fitness 0.859053
#
# testing instance 44
# --Fitness 0.868701
#
# testing instance 45
# --Fitness 0.866216
#
# testing instance 46
# --Fitness 0.866787
#
# testing instance 47
# --Fitness 0.867087
#
# testing instance 48
# --Fitness 0.856731
#
# testing instance 49
# --Fitness 0.866345
#
# Generation 7 Best fitness (5-fold mae cv): 0.870920
# Generation 8
#
# testing instance 5
# --Fitness 0.863346
#
# testing instance 6
# --Fitness 0.866139
#
# testing instance 7
# --Fitness 0.861486
#
# testing instance 8
# --Fitness 0.863195
#
# testing instance 9
# --Fitness 0.867546
#
# testing instance 10
# --Fitness 0.867546
#
# testing instance 11
# --Fitness 0.862239
#
# testing instance 12
# --Fitness 0.861032
#
# testing instance 13
# --Fitness 0.861582
#
# testing instance 14
# --Fitness 0.868331
#
# testing instance 15
# --Fitness 0.867382
#
# testing instance 16
# --Fitness 0.866182
#
# testing instance 17
# --Fitness 0.864200
#
# testing instance 18
# --Fitness 0.867087
#
# testing instance 19
# --Fitness 0.868120
#
# testing instance 20
# --Fitness 0.860321
#
# testing instance 21
# --Fitness 0.866653
#
# testing instance 22
# --Fitness 0.863346
#
# testing instance 23
# --Fitness 0.864134
#
# testing instance 24
# --Fitness 0.858979
#
# testing instance 25
# --Fitness 0.866195
#
# testing instance 26
# --Fitness 0.864814
#
# testing instance 27
# --Fitness 0.864355
#
# testing instance 28
# --Fitness 0.863844
#
# testing instance 29
# --Fitness 0.864513
#
# testing instance 30
# --Fitness 0.860625
#
# testing instance 31
# --Fitness 0.865042
#
# testing instance 32
# --Fitness 0.861987
#
# testing instance 33
# --Fitness 0.866773
#
# testing instance 34
# --Fitness 0.862888
#
# testing instance 35
# --Fitness 0.861909
#
# testing instance 36
# --Fitness 0.861643
#
# testing instance 37
# --Fitness 0.865232
#
# testing instance 38
# --Fitness 0.863346
#
# testing instance 39
# --Fitness 0.859287
#
# testing instance 40
# --Fitness 0.868327
#
# testing instance 41
# --Fitness 0.861548
#
# testing instance 42
# --Fitness 0.870710
#
# testing instance 43
# --Fitness 0.861894
#
# testing instance 44
# --Fitness 0.869268
#
# testing instance 45
# --Fitness 0.862763
#
# testing instance 46
# --Fitness 0.871251
#
# testing instance 47
# --Fitness 0.861609
#
# testing instance 48
# --Fitness 0.864767
#
# testing instance 49
# --Fitness 0.859264
#
# Generation 8 Best fitness (5-fold mae cv): 0.871251
# Generation 9
#
# testing instance 5
# --Fitness 0.862881
#
# testing instance 6
# --Fitness 0.864478
#
# testing instance 7
# --Fitness 0.869209
#
# testing instance 8
# --Fitness 0.868695
#
# testing instance 9
# --Fitness 0.862176
#
# testing instance 10
# --Fitness 0.868754
#
# testing instance 11
# --Fitness 0.866221
#
# testing instance 12
# --Fitness 0.863761
#
# testing instance 13
# --Fitness 0.867022
#
# testing instance 14
# --Fitness 0.857864
#
# testing instance 15
# --Fitness 0.860533
#
# testing instance 16
# --Fitness 0.867582
#
# testing instance 17
# --Fitness 0.863104
#
# testing instance 18
# --Fitness 0.867401
#
# testing instance 19
# --Fitness 0.864602
#
# testing instance 20
# --Fitness 0.862968
#
# testing instance 21
# --Fitness 0.861070
#
# testing instance 22
# --Fitness 0.865042
#
# testing instance 23
# --Fitness 0.862949
#
# testing instance 24
# --Fitness 0.866773
#
# testing instance 25
# --Fitness 0.858949
#
# testing instance 26
# --Fitness 0.864595
#
# testing instance 27
# --Fitness 0.870710
#
# testing instance 28
# --Fitness 0.870465
#
# testing instance 29
# --Fitness 0.867313
#
# testing instance 30
# --Fitness 0.867546
#
# testing instance 31
# --Fitness 0.863518
#
# testing instance 32
# --Fitness 0.869696
#
# testing instance 33
# --Fitness 0.867546
#
# testing instance 34
# --Fitness 0.870710
#
# testing instance 35
# --Fitness 0.864355
#
# testing instance 36
# --Fitness 0.864812
#
# testing instance 37
# --Fitness 0.866139
#
# testing instance 38
# --Fitness 0.861684
#
# testing instance 39
# --Fitness 0.866239
#
# testing instance 40
# --Fitness 0.863586
#
# testing instance 41
# --Fitness 0.863394
#
# testing instance 42
# --Fitness 0.867185
#
# testing instance 43
# --Fitness 0.871112
#
# testing instance 44
# --Fitness 0.863760
#
# testing instance 45
# --Fitness 0.870465
#
# testing instance 46
# --Fitness 0.863144
#
# testing instance 47
# --Fitness 0.863546
#
# testing instance 48
# --Fitness 0.868866
#
# testing instance 49
# --Fitness 0.865232
#
# Generation 9 Best fitness (5-fold mae cv): 0.871251
# Generation 10
#
# testing instance 5
# --Fitness 0.860785
#
# testing instance 6
# --Fitness 0.866503
#
# testing instance 7
# --Fitness 0.855491
#
# testing instance 8
# --Fitness 0.870710
#
# testing instance 9
# --Fitness 0.858192
#
# testing instance 10
# --Fitness 0.858941
#
# testing instance 11
# --Fitness 0.862529
#
# testing instance 12
# --Fitness 0.860108
#
# testing instance 13
# --Fitness 0.860404
#
# testing instance 14
# --Fitness 0.867382
#
# testing instance 15
# --Fitness 0.870710
#
# testing instance 16
# --Fitness 0.861714
#
# testing instance 17
# --Fitness 0.870710
#
# testing instance 18
# --Fitness 0.866563
#
# testing instance 19
# --Fitness 0.869777
#
# testing instance 20
# --Fitness 0.868478
#
# testing instance 21
# --Fitness 0.870465
#
# testing instance 22
# --Fitness 0.863777
#
# testing instance 23
# --Fitness 0.858656
#
# testing instance 24
# --Fitness 0.869209
#
# testing instance 25
# --Fitness 0.868695
#
# testing instance 26
# --Fitness 0.864271
#
# testing instance 27
# --Fitness 0.869696
#
# testing instance 28
# --Fitness 0.867185
#
# testing instance 29
# --Fitness 0.863690
#
# testing instance 30
# --Fitness 0.865929
#
# testing instance 31
# --Fitness 0.869209
#
# testing instance 32
# --Fitness 0.870710
#
# testing instance 33
# --Fitness 0.865835
#
# testing instance 34
# --Fitness 0.855686
#
# testing instance 35
# --Fitness 0.865748
#
# testing instance 36
# --Fitness 0.870710
#
# testing instance 37
# --Fitness 0.861704
#
# testing instance 38
# --Fitness 0.863144
#
# testing instance 39
# --Fitness 0.864752
#
# testing instance 40
# --Fitness 0.871112
#
# testing instance 41
# --Fitness 0.853498
#
# testing instance 42
# --Fitness 0.870710
#
# testing instance 43
# --Fitness 0.859703
#
# testing instance 44
# --Fitness 0.863226
#
# testing instance 45
# --Fitness 0.869209
#
# testing instance 46
# --Fitness 0.871251
#
# testing instance 47
# --Fitness 0.866622
#
# testing instance 48
# --Fitness 0.865315
#
# testing instance 49
# --Fitness 0.863994
#
# Generation 10 Best fitness (5-fold mae cv): 0.871251
# Generation 11
#
# testing instance 5
# --Fitness 0.867546
#
# testing instance 6
# --Fitness 0.868463
#
# testing instance 7
# --Fitness 0.864661
#
# testing instance 8
# --Fitness 0.869209
#
# testing instance 9
# --Fitness 0.870710
#
# testing instance 10
# --Fitness 0.864539
#
# testing instance 11
# --Fitness 0.860321
#
# testing instance 12
# --Fitness 0.867185
#
# testing instance 13
# --Fitness 0.864370
#
# testing instance 14
# --Fitness 0.869209
#
# testing instance 15
# --Fitness 0.861530
#
# testing instance 16
# --Fitness 0.866233
#
# testing instance 17
# --Fitness 0.862590
#
# testing instance 18
# --Fitness 0.865175
#
# testing instance 19
# --Fitness 0.870710
#
# testing instance 20
# --Fitness 0.863068
#
# testing instance 21
# --Fitness 0.859843
#
# testing instance 22
# --Fitness 0.867511
#
# testing instance 23
# --Fitness 0.870710
#
# testing instance 24
# --Fitness 0.869209
#
# testing instance 25
# --Fitness 0.869209
#
# testing instance 26
# --Fitness 0.871251
#
# testing instance 27
# --Fitness 0.870082
#
# testing instance 28
# --Fitness 0.861374
#
# testing instance 29
# --Fitness 0.865971
#
# testing instance 30
# --Fitness 0.868695
#
# testing instance 31
# --Fitness 0.864464
#
# testing instance 32
# --Fitness 0.868580
#
# testing instance 33
# --Fitness 0.869696
#
# testing instance 34
# --Fitness 0.866073
#
# testing instance 35
# --Fitness 0.858608
#
# testing instance 36
# --Fitness 0.870297
#
# testing instance 37
# --Fitness 0.866100
#
# testing instance 38
# --Fitness 0.863083
#
# testing instance 39
# --Fitness 0.865968
#
# testing instance 40
# --Fitness 0.870920
#
# testing instance 41
# --Fitness 0.861875
#
# testing instance 42
# --Fitness 0.860570
#
# testing instance 43
# --Fitness 0.864057
#
# testing instance 44
# --Fitness 0.864421
#
# testing instance 45
# --Fitness 0.859862
#
# testing instance 46
# --Fitness 0.863068
#
# testing instance 47
# --Fitness 0.864628
#
# testing instance 48
# --Fitness 0.864605
#
# testing instance 49
# --Fitness 0.867185
#
# Generation 11 Best fitness (5-fold mae cv): 0.871251
# Generation 12
#
# testing instance 5
# --Fitness 0.864904
#
# testing instance 6
# --Fitness 0.869209
#
# testing instance 7
# --Fitness 0.865467
#
# testing instance 8
# --Fitness 0.865724
#
# testing instance 9
# --Fitness 0.870710
#
# testing instance 10
# --Fitness 0.863636
#
# testing instance 11
# --Fitness 0.864519
#
# testing instance 12
# --Fitness 0.864529
#
# testing instance 13
# --Fitness 0.870465
#
# testing instance 14
# --Fitness 0.865095
#
# testing instance 15
# --Fitness 0.869242
#
# testing instance 16
# --Fitness 0.857894
#
# testing instance 17
# --Fitness 0.871251
#
# testing instance 18
# --Fitness 0.864140
#
# testing instance 19
# --Fitness 0.870710
#
# testing instance 20
# --Fitness 0.860321
#
# testing instance 21
# --Fitness 0.867571
#
# testing instance 22
# --Fitness 0.867632
#
# testing instance 23
# --Fitness 0.869209
#
# testing instance 24
# --Fitness 0.870082
#
# testing instance 25
# --Fitness 0.863994
#
# testing instance 26
# --Fitness 0.869209
#
# testing instance 27
# --Fitness 0.870044
#
# testing instance 28
# --Fitness 0.861363
#
# testing instance 29
# --Fitness 0.865129
#
# testing instance 30
# --Fitness 0.864535
#
# testing instance 31
# --Fitness 0.858980
#
# testing instance 32
# --Fitness 0.863597
#
# testing instance 33
# --Fitness 0.864535
#
# testing instance 34
# --Fitness 0.871251
#
# testing instance 35
# --Fitness 0.859703
#
# testing instance 36
# --Fitness 0.864446
#
# testing instance 37
# --Fitness 0.867674
#
# testing instance 38
# --Fitness 0.867674
#
# testing instance 39
# --Fitness 0.870710
#
# testing instance 40
# --Fitness 0.870710
#
# testing instance 41
# --Fitness 0.867546
#
# testing instance 42
# --Fitness 0.867674
#
# testing instance 43
# --Fitness 0.868580
#
# testing instance 44
# --Fitness 0.861286
#
# testing instance 45
# --Fitness 0.869209
#
# testing instance 46
# --Fitness 0.868580
#
# testing instance 47
# --Fitness 0.860689
#
# testing instance 48
# --Fitness 0.860266
#
# testing instance 49
# --Fitness 0.858218
#
# Generation 12 Best fitness (5-fold mae cv): 0.871251
# Generation 13
#
# testing instance 5
# --Fitness 0.870044
#
# testing instance 6
# --Fitness 0.864184
#
# testing instance 7
# --Fitness 0.863191
#
# testing instance 8
# --Fitness 0.871251
#
# testing instance 9
# --Fitness 0.867674
#
# testing instance 10
# --Fitness 0.862579
#
# testing instance 11
# --Fitness 0.861656
#
# testing instance 12
# --Fitness 0.866100
#
# testing instance 13
# --Fitness 0.862280
#
# testing instance 14
# --Fitness 0.870710
#
# testing instance 15
# --Fitness 0.864926
#
# testing instance 16
# --Fitness 0.863694
#
# testing instance 17
# --Fitness 0.868580
#
# testing instance 18
# --Fitness 0.863642
#
# testing instance 19
# --Fitness 0.867632
#
# testing instance 20
# --Fitness 0.869209
#
# testing instance 21
# --Fitness 0.869209
#
# testing instance 22
# --Fitness 0.866178
#
# testing instance 23
# --Fitness 0.870044
#
# testing instance 24
# --Fitness 0.864529
#
# testing instance 25
# --Fitness 0.865835
#
# testing instance 26
# --Fitness 0.862793
#
# testing instance 27
# --Fitness 0.867793
#
# testing instance 28
# --Fitness 0.866100
#
# testing instance 29
# --Fitness 0.870710
#
# testing instance 30
# --Fitness 0.866115
#
# testing instance 31
# --Fitness 0.867674
#
# testing instance 32
# --Fitness 0.867767
#
# testing instance 33
# --Fitness 0.867577
#
# testing instance 34
# --Fitness 0.863010
#
# testing instance 35
# --Fitness 0.863591
#
# testing instance 36
# --Fitness 0.867674
#
# testing instance 37
# --Fitness 0.865010
#
# testing instance 38
# --Fitness 0.865095
#
# testing instance 39
# --Fitness 0.867674
#
# testing instance 40
# --Fitness 0.864331
#
# testing instance 41
# --Fitness 0.870044
#
# testing instance 42
# --Fitness 0.866744
#
# testing instance 43
# --Fitness 0.863191
#
# testing instance 44
# --Fitness 0.858839
#
# testing instance 45
# --Fitness 0.871251
#
# testing instance 46
# --Fitness 0.870082
#
# testing instance 47
# --Fitness 0.858703
#
# testing instance 48
# --Fitness 0.870082
#
# testing instance 49
# --Fitness 0.869209
#
# Generation 13 Best fitness (5-fold mae cv): 0.871251
# Generation 14
#
# testing instance 5
# --Fitness 0.868843
#
# testing instance 6
# --Fitness 0.866971
#
# testing instance 7
# --Fitness 0.865161
#
# testing instance 8
# --Fitness 0.867674
#
# testing instance 9
# --Fitness 0.870082
#
# testing instance 10
# --Fitness 0.864184
#
# testing instance 11
# --Fitness 0.871251
#
# testing instance 12
# --Fitness 0.871251
#
# testing instance 13
# --Fitness 0.864446
#
# testing instance 14
# --Fitness 0.860027
#
# testing instance 15
# --Fitness 0.860573
#
# testing instance 16
# --Fitness 0.868843
#
# testing instance 17
# --Fitness 0.864411
#
# testing instance 18
# --Fitness 0.865335
#
# testing instance 19
# --Fitness 0.861686
#
# testing instance 20
# --Fitness 0.867674
#
# testing instance 21
# --Fitness 0.867632
#
# testing instance 22
# --Fitness 0.869209
#
# testing instance 23
# --Fitness 0.862503
#
# testing instance 24
# --Fitness 0.864446
#
# testing instance 25
# --Fitness 0.863191
#
# testing instance 26
# --Fitness 0.867401
#
# testing instance 27
# --Fitness 0.867674
#
# testing instance 28
# --Fitness 0.866177
#
# testing instance 29
# --Fitness 0.867180
#
# testing instance 30
# --Fitness 0.871251
#
# testing instance 31
# --Fitness 0.861623
#
# testing instance 32
# --Fitness 0.867180
#
# testing instance 33
# --Fitness 0.863068
#
# testing instance 34
# --Fitness 0.870082
#
# testing instance 35
# --Fitness 0.865095
#
# testing instance 36
# --Fitness 0.864446
#
# testing instance 37
# --Fitness 0.869209
#
# testing instance 38
# --Fitness 0.871126
#
# testing instance 39
# --Fitness 0.864491
#
# testing instance 40
# --Fitness 0.867401
#
# testing instance 41
# --Fitness 0.867674
#
# testing instance 42
# --Fitness 0.866939
#
# testing instance 43
# --Fitness 0.869234
#
# testing instance 44
# --Fitness 0.870044
#
# testing instance 45
# --Fitness 0.870044
#
# testing instance 46
# --Fitness 0.867674
#
# testing instance 47
# --Fitness 0.870710
#
# testing instance 48
# --Fitness 0.861887
#
# testing instance 49
# --Fitness 0.863506
#
# Generation 14 Best fitness (5-fold mae cv): 0.871251
# Generation 15
#
# testing instance 5
# --Fitness 0.871251
#
# testing instance 6
# --Fitness 0.863951
#
# testing instance 7
# --Fitness 0.861826
#
# testing instance 8
# --Fitness 0.864943
#
# testing instance 9
# --Fitness 0.862193
#
# testing instance 10
# --Fitness 0.863611
#
# testing instance 11
# --Fitness 0.862317
#
# testing instance 12
# --Fitness 0.870060
#
# testing instance 13
# --Fitness 0.871251
#
# testing instance 14
# --Fitness 0.869209
#
# testing instance 15
# --Fitness 0.871251
#
# testing instance 16
# --Fitness 0.867674
#
# testing instance 17
# --Fitness 0.863545
#
# testing instance 18
# --Fitness 0.861109
#
# testing instance 19
# --Fitness 0.854441
#
# testing instance 20
# --Fitness 0.870710
#
# testing instance 21
# --Fitness 0.871251
#
# testing instance 22
# --Fitness 0.867674
#
# testing instance 23
# --Fitness 0.867674
#
# testing instance 24
# --Fitness 0.862151
#
# testing instance 25
# --Fitness 0.868843
#
# testing instance 26
# --Fitness 0.860393
#
# testing instance 27
# --Fitness 0.867674
#
# testing instance 28
# --Fitness 0.871251
#
# testing instance 29
# --Fitness 0.865801
#
# testing instance 30
# --Fitness 0.867156
#
# testing instance 31
# --Fitness 0.862785
#
# testing instance 32
# --Fitness 0.871251
#
# testing instance 33
# --Fitness 0.871251
#
# testing instance 34
# --Fitness 0.870082
#
# testing instance 35
# --Fitness 0.869209
#
# testing instance 36
# --Fitness 0.871251
#
# testing instance 37
# --Fitness 0.867313
#
# testing instance 38
# --Fitness 0.870082
#
# testing instance 39
# --Fitness 0.864881
#
# testing instance 40
# --Fitness 0.871251
#
# testing instance 41
# --Fitness 0.867535
#
# testing instance 42
# --Fitness 0.862462
#
# testing instance 43
# --Fitness 0.871251
#
# testing instance 44
# --Fitness 0.865095
#
# testing instance 45
# --Fitness 0.867674
#
# testing instance 46
# --Fitness 0.870082
#
# testing instance 47
# --Fitness 0.870082
#
# testing instance 48
# --Fitness 0.870710
#
# testing instance 49
# --Fitness 0.870044
#
# Generation 15 Best fitness (5-fold mae cv): 0.871251
# Generation 16
#
# testing instance 5
# --Fitness 0.870963
#
# testing instance 6
# --Fitness 0.859165
#
# testing instance 7
# --Fitness 0.871251
#
# testing instance 8
# --Fitness 0.867055
#
# testing instance 9
# --Fitness 0.864286
#
# testing instance 10
# --Fitness 0.869334
#
# testing instance 11
# --Fitness 0.859683
#
# testing instance 12
# --Fitness 0.868690
#
# testing instance 13
# --Fitness 0.868867
#
# testing instance 14
# --Fitness 0.871082
#
# testing instance 15
# --Fitness 0.868843
#
# testing instance 16
# --Fitness 0.867574
#
# testing instance 17
# --Fitness 0.871251
#
# testing instance 18
# --Fitness 0.871251
#
# testing instance 19
# --Fitness 0.871251
#
# testing instance 20
# --Fitness 0.868843
#
# testing instance 21
# --Fitness 0.870082
#
# testing instance 22
# --Fitness 0.864446
#
# testing instance 23
# --Fitness 0.870044
#
# testing instance 24
# --Fitness 0.858368
#
# testing instance 25
# --Fitness 0.865050
#
# testing instance 26
# --Fitness 0.863083
#
# testing instance 27
# --Fitness 0.862886
#
# testing instance 28
# --Fitness 0.871039
#
# testing instance 29
# --Fitness 0.866273
#
# testing instance 30
# --Fitness 0.865467
#
# testing instance 31
# --Fitness 0.863478
#
# testing instance 32
# --Fitness 0.862621
#
# testing instance 33
# --Fitness 0.863971
#
# testing instance 34
# --Fitness 0.858427
#
# testing instance 35
# --Fitness 0.867674
#
# testing instance 36
# --Fitness 0.871251
#
# testing instance 37
# --Fitness 0.863195
#
# testing instance 38
# --Fitness 0.867180
#
# testing instance 39
# --Fitness 0.864418
#
# testing instance 40
# --Fitness 0.864892
#
# testing instance 41
# --Fitness 0.866593
#
# testing instance 42
# --Fitness 0.859312
#
# testing instance 43
# --Fitness 0.867674
#
# testing instance 44
# --Fitness 0.867674
#
# testing instance 45
# --Fitness 0.867674
#
# testing instance 46
# --Fitness 0.867180
#
# testing instance 47
# --Fitness 0.863908
#
# testing instance 48
# --Fitness 0.865049
#
# testing instance 49
# --Fitness 0.871251
#
# Generation 16 Best fitness (5-fold mae cv): 0.871251
# Generation 17
#
# testing instance 5
# --Fitness 0.866273
#
# testing instance 6
# --Fitness 0.862027
#
# testing instance 7
# --Fitness 0.866232
#
# testing instance 8
# --Fitness 0.867574
#
# testing instance 9
# --Fitness 0.863558
#
# testing instance 10
# --Fitness 0.871251
#
# testing instance 11
# --Fitness 0.863822
#
# testing instance 12
# --Fitness 0.871039
#
# testing instance 13
# --Fitness 0.868626
#
# testing instance 14
# --Fitness 0.867674
#
# testing instance 15
# --Fitness 0.871251
#
# testing instance 16
# --Fitness 0.871251
#
# testing instance 17
# --Fitness 0.871251
#
# testing instance 18
# --Fitness 0.871251
#
# testing instance 19
# --Fitness 0.867674
#
# testing instance 20
# --Fitness 0.864098
#
# testing instance 21
# --Fitness 0.871251
#
# testing instance 22
# --Fitness 0.868168
#
# testing instance 23
# --Fitness 0.871251
#
# testing instance 24
# --Fitness 0.862026
#
# testing instance 25
# --Fitness 0.861279
#
# testing instance 26
# --Fitness 0.867674
#
# testing instance 27
# --Fitness 0.871126
#
# testing instance 28
# --Fitness 0.868568
#
# testing instance 29
# --Fitness 0.869334
#
# testing instance 30
# --Fitness 0.868138
#
# testing instance 31
# --Fitness 0.864917
#
# testing instance 32
# --Fitness 0.862642
#
# testing instance 33
# --Fitness 0.865167
#
# testing instance 34
# --Fitness 0.864590
#
# testing instance 35
# --Fitness 0.863191
#
# testing instance 36
# --Fitness 0.871039
#
# testing instance 37
# --Fitness 0.867757
#
# testing instance 38
# --Fitness 0.861947
#
# testing instance 39
# --Fitness 0.862753
#
# testing instance 40
# --Fitness 0.871251
#
# testing instance 41
# --Fitness 0.868343
#
# testing instance 42
# --Fitness 0.871126
#
# testing instance 43
# --Fitness 0.861610
#
# testing instance 44
# --Fitness 0.871251
#
# testing instance 45
# --Fitness 0.867574
#
# testing instance 46
# --Fitness 0.871251
#
# testing instance 47
# --Fitness 0.859805
#
# testing instance 48
# --Fitness 0.869524
#
# testing instance 49
# --Fitness 0.861766
#
# Generation 17 Best fitness (5-fold mae cv): 0.871251
# Generation 18
#
# testing instance 5
# --Fitness 0.871251
#
# testing instance 6
# --Fitness 0.869524
#
# testing instance 7
# --Fitness 0.861267
#
# testing instance 8
# --Fitness 0.868988
#
# testing instance 9
# --Fitness 0.865001
#
# testing instance 10
# --Fitness 0.864778
#
# testing instance 11
# --Fitness 0.869524
#
# testing instance 12
# --Fitness 0.871126
#
# testing instance 13
# --Fitness 0.863932
#
# testing instance 14
# --Fitness 0.868568
#
# testing instance 15
# --Fitness 0.857388
#
# testing instance 16
# --Fitness 0.860508
#
# testing instance 17
# --Fitness 0.871126
#
# testing instance 18
# --Fitness 0.868636
#
# testing instance 19
# --Fitness 0.871039
#
# testing instance 20
# --Fitness 0.867674
#
# testing instance 21
# --Fitness 0.871251
#
# testing instance 22
# --Fitness 0.865812
#
# testing instance 23
# --Fitness 0.871039
#
# testing instance 24
# --Fitness 0.871251
#
# testing instance 25
# --Fitness 0.868322
#
# testing instance 26
# --Fitness 0.866241
#
# testing instance 27
# --Fitness 0.868626
#
# testing instance 28
# --Fitness 0.862097
#
# testing instance 29
# --Fitness 0.868924
#
# testing instance 30
# --Fitness 0.871126
#
# testing instance 31
# --Fitness 0.864411
#
# testing instance 32
# --Fitness 0.866213
#
# testing instance 33
# --Fitness 0.864521
#
# testing instance 34
# --Fitness 0.861538
#
# testing instance 35
# --Fitness 0.865189
#
# testing instance 36
# --Fitness 0.871251
#
# testing instance 37
# --Fitness 0.868626
#
# testing instance 38
# --Fitness 0.867872
#
# testing instance 39
# --Fitness 0.866036
#
# testing instance 40
# --Fitness 0.871251
#
# testing instance 41
# --Fitness 0.871251
#
# testing instance 42
# --Fitness 0.869232
#
# testing instance 43
# --Fitness 0.865038
#
# testing instance 44
# --Fitness 0.865575
#
# testing instance 45
# --Fitness 0.867158
#
# testing instance 46
# --Fitness 0.871126
#
# testing instance 47
# --Fitness 0.864793
#
# testing instance 48
# --Fitness 0.863189
#
# testing instance 49
# --Fitness 0.871126
#
# Generation 18 Best fitness (5-fold mae cv): 0.871251
# Generation 19
#
# testing instance 5
# --Fitness 0.868435
#
# testing instance 6
# --Fitness 0.869253
#
# testing instance 7
# --Fitness 0.869232
#
# testing instance 8
# --Fitness 0.871251
#
# testing instance 9
# --Fitness 0.863754
#
# testing instance 10
# --Fitness 0.858292
#
# testing instance 11
# --Fitness 0.865731
#
# testing instance 12
# --Fitness 0.866909
#
# testing instance 13
# --Fitness 0.871126
#
# testing instance 14
# --Fitness 0.866273
#
# testing instance 15
# --Fitness 0.871251
#
# testing instance 16
# --Fitness 0.871251
#
# testing instance 17
# --Fitness 0.871126
#
# testing instance 18
# --Fitness 0.863145
#
# testing instance 19
# --Fitness 0.871126
#
# testing instance 20
# --Fitness 0.871251
#
# testing instance 21
# --Fitness 0.871126
#
# testing instance 22
# --Fitness 0.864411
#
# testing instance 23
# --Fitness 0.861335
#
# testing instance 24
# --Fitness 0.867674
#
# testing instance 25
# --Fitness 0.871251
#
# testing instance 26
# --Fitness 0.870549
#
# testing instance 27
# --Fitness 0.868988
#
# testing instance 28
# --Fitness 0.863784
#
# testing instance 29
# --Fitness 0.864411
#
# testing instance 30
# --Fitness 0.868626
#
# testing instance 31
# --Fitness 0.871126
#
# testing instance 32
# --Fitness 0.863068
#
# testing instance 33
# --Fitness 0.871251
#
# testing instance 34
# --Fitness 0.861034
#
# testing instance 35
# --Fitness 0.870063
#
# testing instance 36
# --Fitness 0.869524
#
# testing instance 37
# --Fitness 0.871126
#
# testing instance 38
# --Fitness 0.862569
#
# testing instance 39
# --Fitness 0.871251
#
# testing instance 40
# --Fitness 0.871126
#
# testing instance 41
# --Fitness 0.871251
#
# testing instance 42
# --Fitness 0.868770
#
# testing instance 43
# --Fitness 0.871126
#
# testing instance 44
# --Fitness 0.871126
#
# testing instance 45
# --Fitness 0.873108
#
# testing instance 46
# --Fitness 0.863525
#
# testing instance 47
# --Fitness 0.871251
#
# testing instance 48
# --Fitness 0.859840
#
# testing instance 49
# --Fitness 0.873108
#
# Generation 19 Best fitness (5-fold mae cv): 0.873108
# Generation 20
#
# testing instance 5
# --Fitness 0.871251
#
# testing instance 6
# --Fitness 0.873108
#
# testing instance 7
# --Fitness 0.856470
#
# testing instance 8
# --Fitness 0.871039
#
# testing instance 9
# --Fitness 0.867497
#
# testing instance 10
# --Fitness 0.871251
#
# testing instance 11
# --Fitness 0.871126
#
# testing instance 12
# --Fitness 0.867674
#
# testing instance 13
# --Fitness 0.871126
#
# testing instance 14
# --Fitness 0.869524
#
# testing instance 15
# --Fitness 0.871251
#
# testing instance 16
# --Fitness 0.868703
#
# testing instance 17
# --Fitness 0.871126
#
# testing instance 18
# --Fitness 0.871251
#
# testing instance 19
# --Fitness 0.867776
#
# testing instance 20
# --Fitness 0.871251
#
# testing instance 21
# --Fitness 0.871039
#
# testing instance 22
# --Fitness 0.861440
#
# testing instance 23
# --Fitness 0.859821
#
# testing instance 24
# --Fitness 0.871251
#
# testing instance 25
# --Fitness 0.871251
#
# testing instance 26
# --Fitness 0.867412
#
# testing instance 27
# --Fitness 0.871251
#
# testing instance 28
# --Fitness 0.867403
#
# testing instance 29
# --Fitness 0.862645
#
# testing instance 30
# --Fitness 0.864154
#
# testing instance 31
# --Fitness 0.867674
#
# testing instance 32
# --Fitness 0.871251
#
# testing instance 33
# --Fitness 0.862580
#
# testing instance 34
# --Fitness 0.867180
#
# testing instance 35
# --Fitness 0.867674
#
# testing instance 36
# --Fitness 0.870181
#
# testing instance 37
# --Fitness 0.871126
#
# testing instance 38
# --Fitness 0.871251
#
# testing instance 39
# --Fitness 0.866429
#
# testing instance 40
# --Fitness 0.871126
#
# testing instance 41
# --Fitness 0.871126
#
# testing instance 42
# --Fitness 0.871039
#
# testing instance 43
# --Fitness 0.871251
#
# testing instance 44
# --Fitness 0.859165
#
# testing instance 45
# --Fitness 0.870286
#
# testing instance 46
# --Fitness 0.871251
#
# testing instance 47
# --Fitness 0.871251
#
# testing instance 48
# --Fitness 0.864411
#
# testing instance 49
# --Fitness 0.871251
#
# Generation 20 Best fitness (5-fold mae cv): 0.873108
# Generation 21
#
# testing instance 5
# --Fitness 0.861279
#
# testing instance 6
# --Fitness 0.871251
#
# testing instance 7
# --Fitness 0.871251
#
# testing instance 8
# --Fitness 0.871251
#
# testing instance 9
# --Fitness 0.859165
#
# testing instance 10
# --Fitness 0.871126
#
# testing instance 11
# --Fitness 0.871251
#
# testing instance 12
# --Fitness 0.871251
#
# testing instance 13
# --Fitness 0.871251
#
# testing instance 14
# --Fitness 0.871522
#
# testing instance 15
# --Fitness 0.866889
#
# testing instance 16
# --Fitness 0.868945
#
# testing instance 17
# --Fitness 0.863784
#
# testing instance 18
# --Fitness 0.867535
#
# testing instance 19
# --Fitness 0.866383
#
# testing instance 20
# --Fitness 0.873088
#
# testing instance 21
# --Fitness 0.866382
#
# testing instance 22
# --Fitness 0.864952
#
# testing instance 23
# --Fitness 0.862765
#
# testing instance 24
# --Fitness 0.860233
#
# testing instance 25
# --Fitness 0.869524
#
# testing instance 26
# --Fitness 0.865979
#
# testing instance 27
# --Fitness 0.871126
#
# testing instance 28
# --Fitness 0.871251
#
# testing instance 29
# --Fitness 0.871251
#
# testing instance 30
# --Fitness 0.871126
#
# testing instance 31
# --Fitness 0.867377
#
# testing instance 32
# --Fitness 0.869524
#
# testing instance 33
# --Fitness 0.871251
#
# testing instance 34
# --Fitness 0.869116
#
# testing instance 35
# --Fitness 0.871251
#
# testing instance 36
# --Fitness 0.871251
#
# testing instance 37
# --Fitness 0.863181
#
# testing instance 38
# --Fitness 0.871126
#
# testing instance 39
# --Fitness 0.861508
#
# testing instance 40
# --Fitness 0.866690
#
# testing instance 41
# --Fitness 0.871251
#
# testing instance 42
# --Fitness 0.871251
#
# testing instance 43
# --Fitness 0.867674
#
# testing instance 44
# --Fitness 0.860022
#
# testing instance 45
# --Fitness 0.864503
#
# testing instance 46
# --Fitness 0.871126
#
# testing instance 47
# --Fitness 0.869830
#
# testing instance 48
# --Fitness 0.865140
#
# testing instance 49
# --Fitness 0.871251
#
# Generation 21 Best fitness (5-fold mae cv): 0.873108
# Generation 22
#
# testing instance 5
# --Fitness 0.871126
#
# testing instance 6
# --Fitness 0.871126
#
# testing instance 7
# --Fitness 0.871251
#
# testing instance 8
# --Fitness 0.868140
#
# testing instance 9
# --Fitness 0.864505
#
# testing instance 10
# --Fitness 0.865167
#
# testing instance 11
# --Fitness 0.873108
#
# testing instance 12
# --Fitness 0.873088
#
# testing instance 13
# --Fitness 0.867319
#
# testing instance 14
# --Fitness 0.873108
#
# testing instance 15
# --Fitness 0.862673
#
# testing instance 16
# --Fitness 0.871251
#
# testing instance 17
# --Fitness 0.871039
#
# testing instance 18
# --Fitness 0.865354
#
# testing instance 19
# --Fitness 0.871251
#
# testing instance 20
# --Fitness 0.871251
#
# testing instance 21
# --Fitness 0.867674
#
# testing instance 22
# --Fitness 0.871039
#
# testing instance 23
# --Fitness 0.867674
#
# testing instance 24
# --Fitness 0.858368
#
# testing instance 25
# --Fitness 0.871126
#
# testing instance 26
# --Fitness 0.862331
#
# testing instance 27
# --Fitness 0.871251
#
# testing instance 28
# --Fitness 0.871126
#
# testing instance 29
# --Fitness 0.871251
#
# testing instance 30
# --Fitness 0.871251
#
# testing instance 31
# --Fitness 0.871251
#
# testing instance 32
# --Fitness 0.871251
#
# testing instance 33
# --Fitness 0.871251
#
# testing instance 34
# --Fitness 0.855694
#
# testing instance 35
# --Fitness 0.871522
#
# testing instance 36
# --Fitness 0.863994
#
# testing instance 37
# --Fitness 0.871126
#
# testing instance 38
# --Fitness 0.871251
#
# testing instance 39
# --Fitness 0.860863
#
# testing instance 40
# --Fitness 0.867674
#
# testing instance 41
# --Fitness 0.859165
#
# testing instance 42
# --Fitness 0.871251
#
# testing instance 43
# --Fitness 0.867674
#
# testing instance 44
# --Fitness 0.871251
#
# testing instance 45
# --Fitness 0.854860
#
# testing instance 46
# --Fitness 0.873088
#
# testing instance 47
# --Fitness 0.871251
#
# testing instance 48
# --Fitness 0.865434
#
# testing instance 49
# --Fitness 0.866429
#
# Generation 22 Best fitness (5-fold mae cv): 0.873108
# Generation 23
#
# testing instance 5
# --Fitness 0.871126
#
# testing instance 6
# --Fitness 0.863994
#
# testing instance 7
# --Fitness 0.871126
#
# testing instance 8
# --Fitness 0.873088
#
# testing instance 9
# --Fitness 0.863320
#
# testing instance 10
# --Fitness 0.869057
#
# testing instance 11
# --Fitness 0.869524
#
# testing instance 12
# --Fitness 0.862519
#
# testing instance 13
# --Fitness 0.863145
#
# testing instance 14
# --Fitness 0.864707
#
# testing instance 15
# --Fitness 0.860566
#
# testing instance 16
# --Fitness 0.873108
#
# testing instance 17
# --Fitness 0.871251
#
# testing instance 18
# --Fitness 0.866909
#
# testing instance 19
# --Fitness 0.871251
#
# testing instance 20
# --Fitness 0.860892
#
# testing instance 21
# --Fitness 0.873088
#
# testing instance 22
# --Fitness 0.862655
#
# testing instance 23
# --Fitness 0.873108
#
# testing instance 24
# --Fitness 0.871251
#
# testing instance 25
# --Fitness 0.873108
#
# testing instance 26
# --Fitness 0.868926
#
# testing instance 27
# --Fitness 0.871251
#
# testing instance 28
# --Fitness 0.864213
#
# testing instance 29
# --Fitness 0.871251
#
# testing instance 30
# --Fitness 0.864052
#
# testing instance 31
# --Fitness 0.864213
#
# testing instance 32
# --Fitness 0.871251
#
# testing instance 33
# --Fitness 0.863271
#
# testing instance 34
# --Fitness 0.871251
#
# testing instance 35
# --Fitness 0.864213
#
# testing instance 36
# --Fitness 0.865670
#
# testing instance 37
# --Fitness 0.863994
#
# testing instance 38
# --Fitness 0.871251
#
# testing instance 39
# --Fitness 0.873088
#
# testing instance 40
# --Fitness 0.873088
#
# testing instance 41
# --Fitness 0.868467
#
# testing instance 42
# --Fitness 0.868885
#
# testing instance 43
# --Fitness 0.871251
#
# testing instance 44
# --Fitness 0.871251
#
# testing instance 45
# --Fitness 0.871251
#
# testing instance 46
# --Fitness 0.865189
#
# testing instance 47
# --Fitness 0.871126
#
# testing instance 48
# --Fitness 0.863156
#
# testing instance 49
# --Fitness 0.869524
#
# Generation 23 Best fitness (5-fold mae cv): 0.873108
# Generation 24
#
# testing instance 5
# --Fitness 0.868168
#
# testing instance 6
# --Fitness 0.869524
#
# testing instance 7
# --Fitness 0.871126
#
# testing instance 8
# --Fitness 0.871251
#
# testing instance 9
# --Fitness 0.862709
#
# testing instance 10
# --Fitness 0.862298
#
# testing instance 11
# --Fitness 0.867680
#
# testing instance 12
# --Fitness 0.871251
#
# testing instance 13
# --Fitness 0.871126
#
# testing instance 14
# --Fitness 0.871126
#
# testing instance 15
# --Fitness 0.865047
#
# testing instance 16
# --Fitness 0.864720
#
# testing instance 17
# --Fitness 0.871251
#
# testing instance 18
# --Fitness 0.871126
#
# testing instance 19
# --Fitness 0.871251
#
# testing instance 20
# --Fitness 0.868168
#
# testing instance 21
# --Fitness 0.864411
#
# testing instance 22
# --Fitness 0.871039
#
# testing instance 23
# --Fitness 0.871251
#
# testing instance 24
# --Fitness 0.861508
#
# testing instance 25
# --Fitness 0.871126
#
# testing instance 26
# --Fitness 0.862349
#
# testing instance 27
# --Fitness 0.873108
#
# testing instance 28
# --Fitness 0.873108
#
# testing instance 29
# --Fitness 0.863690
#
# testing instance 30
# --Fitness 0.867674
#
# testing instance 31
# --Fitness 0.873108
#
# testing instance 32
# --Fitness 0.862860
#
# testing instance 33
# --Fitness 0.873108
#
# testing instance 34
# --Fitness 0.862519
#
# testing instance 35
# --Fitness 0.871039
#
# testing instance 36
# --Fitness 0.873108
#
# testing instance 37
# --Fitness 0.862795
#
# testing instance 38
# --Fitness 0.871251
#
# testing instance 39
# --Fitness 0.873088
#
# testing instance 40
# --Fitness 0.871251
#
# testing instance 41
# --Fitness 0.869341
#
# testing instance 42
# --Fitness 0.864223
#
# testing instance 43
# --Fitness 0.869250
#
# testing instance 44
# --Fitness 0.864382
#
# testing instance 45
# --Fitness 0.873088
#
# testing instance 46
# --Fitness 0.873108
#
# testing instance 47
# --Fitness 0.871251
#
# testing instance 48
# --Fitness 0.866020
#
# testing instance 49
# --Fitness 0.871126
#
# Generation 24 Best fitness (5-fold mae cv): 0.873108
# Generation 25
#
# testing instance 5
# --Fitness 0.871251
#
# testing instance 6
# --Fitness 0.871126
#
# testing instance 7
# --Fitness 0.871251
#
# testing instance 8
# --Fitness 0.873108
#
# testing instance 9
# --Fitness 0.871039
#
# testing instance 10
# --Fitness 0.871126
#
# testing instance 11
# --Fitness 0.871126
#
# testing instance 12
# ...
# --Fitness 0.865859
#
# testing instance 34
# --Fitness 0.873108
#
# testing instance 35
# --Fitness 0.873108
#
# testing instance 36
# --Fitness 0.865135
#
# testing instance 37
# --Fitness 0.868732
#
# testing instance 38
# --Fitness 0.873108
#
# testing instance 39
# --Fitness 0.870488
#
# testing instance 40
# --Fitness 0.873108
#
# testing instance 41
# --Fitness 0.873108
#
# testing instance 42
# --Fitness 0.873108
#
# testing instance 43
# --Fitness 0.867016
#
# testing instance 44
# --Fitness 0.873108
#
# testing instance 45
# --Fitness 0.868782
#
# testing instance 46
# --Fitness 0.873108
#
# testing instance 47
# --Fitness 0.873108
#
# testing instance 48
# --Fitness 0.859595
#
# testing instance 49
# --Fitness 0.873108
#
# Generation 91 Best fitness (5-fold mae cv): 0.873108
# Generation 92
#
# testing instance 5
# --Fitness 0.861341
#
# testing instance 6
# --Fitness 0.873108
#
# testing instance 7
# --Fitness 0.873108
#
# testing instance 8
# --Fitness 0.866060
#
# testing instance 9
# --Fitness 0.859265
#
# testing instance 10
# --Fitness 0.873108
#
# testing instance 11
# --Fitness 0.866438
#
# testing instance 12
# --Fitness 0.866503
#
# testing instance 13
# --Fitness 0.859224
#
# testing instance 14
# --Fitness 0.865889
#
# testing instance 15
# --Fitness 0.873108
#
# testing instance 16
# --Fitness 0.873108
#
# testing instance 17
# --Fitness 0.867199
#
# testing instance 18
# --Fitness 0.873108
#
# testing instance 19
# --Fitness 0.865831
#
# testing instance 20
# --Fitness 0.873108
#
# testing instance 21
# --Fitness 0.873108
#
# testing instance 22
# --Fitness 0.873108
#
# testing instance 23
# --Fitness 0.873108
#
# testing instance 24
# --Fitness 0.865129
#
# testing instance 25
# --Fitness 0.864055
#
# testing instance 26
# --Fitness 0.873108
#
# testing instance 27
# --Fitness 0.863241
#
# testing instance 28
# --Fitness 0.873108
#
# testing instance 29
# --Fitness 0.867457
#
# testing instance 30
# --Fitness 0.863463
#
# testing instance 31
# --Fitness 0.866130
#
# testing instance 32
# --Fitness 0.873108
#
# testing instance 33
# --Fitness 0.870488
#
# testing instance 34
# --Fitness 0.866097
#
# testing instance 35
# --Fitness 0.873108
#
# testing instance 36
# --Fitness 0.873108
#
# testing instance 37
# --Fitness 0.867567
#
# testing instance 38
# --Fitness 0.873108
#
# testing instance 39
# --Fitness 0.873108
#
# testing instance 40
# --Fitness 0.873108
#
# testing instance 41
# --Fitness 0.865474
#
# testing instance 42
# --Fitness 0.868586
#
# testing instance 43
# --Fitness 0.870549
#
# testing instance 44
# --Fitness 0.873108
#
# testing instance 45
# --Fitness 0.873108
#
# testing instance 46
# --Fitness 0.873108
#
# testing instance 47
# --Fitness 0.873108
#
# testing instance 48
# --Fitness 0.873108
#
# testing instance 49
# --Fitness 0.865894
#
# Generation 92 Best fitness (5-fold mae cv): 0.873108
# Generation 93
#
# testing instance 5
# --Fitness 0.873108
#
# testing instance 6
# --Fitness 0.873108
#
# testing instance 7
# --Fitness 0.865687
#
# testing instance 8
# --Fitness 0.873108
#
# testing instance 9
# --Fitness 0.868168
#
# testing instance 10
# --Fitness 0.873108
#
# testing instance 11
# --Fitness 0.872845
#
# testing instance 12
# --Fitness 0.870488
#
# testing instance 13
# --Fitness 0.862019
#
# testing instance 14
# --Fitness 0.873108
#
# testing instance 15
# --Fitness 0.869221
#
# testing instance 16
# --Fitness 0.866273
#
# testing instance 17
# --Fitness 0.873108
#
# testing instance 18
# --Fitness 0.873108
#
# testing instance 19
# --Fitness 0.870871
#
# testing instance 20
# --Fitness 0.873108
#
# testing instance 21
# --Fitness 0.873108
#
# testing instance 22
# --Fitness 0.862751
#
# testing instance 23
# --Fitness 0.859774
#
# testing instance 24
# --Fitness 0.864864
#
# testing instance 25
# --Fitness 0.873108
#
# testing instance 26
# --Fitness 0.866352
#
# testing instance 27
# --Fitness 0.866473
#
# testing instance 28
# --Fitness 0.873108
#
# testing instance 29
# --Fitness 0.857918
#
# testing instance 30
# --Fitness 0.873108
#
# testing instance 31
# --Fitness 0.873108
#
# testing instance 32
# --Fitness 0.864587
#
# testing instance 33
# --Fitness 0.854777
#
# testing instance 34
# --Fitness 0.859774
#
# testing instance 35
# --Fitness 0.873108
#
# testing instance 36
# --Fitness 0.873108
#
# testing instance 37
# --Fitness 0.865279
#
# testing instance 38
# --Fitness 0.873108
#
# testing instance 39
# --Fitness 0.863162
#
# testing instance 40
# --Fitness 0.857089
#
# testing instance 41
# --Fitness 0.865062
#
# testing instance 42
# --Fitness 0.873108
#
# testing instance 43
# --Fitness 0.862053
#
# testing instance 44
# --Fitness 0.873108
#
# testing instance 45
# --Fitness 0.862277
#
# testing instance 46
# --Fitness 0.873108
#
# testing instance 47
# --Fitness 0.873108
#
# testing instance 48
# --Fitness 0.873108
#
# testing instance 49
# --Fitness 0.870773
#
# Generation 93 Best fitness (5-fold mae cv): 0.873108
# Generation 94
#
# testing instance 5
# --Fitness 0.873108
#
# testing instance 6
# --Fitness 0.873108
#
# testing instance 7
# --Fitness 0.859267
#
# testing instance 8
# --Fitness 0.873108
#
# testing instance 9
# --Fitness 0.873108
#
# testing instance 10
# --Fitness 0.862034
#
# testing instance 11
# --Fitness 0.865970
#
# testing instance 12
# --Fitness 0.863229
#
# testing instance 13
# --Fitness 0.873108
#
# testing instance 14
# --Fitness 0.867136
#
# testing instance 15
# --Fitness 0.873108
#
# testing instance 16
# --Fitness 0.873108
#
# testing instance 17
# --Fitness 0.873108
#
# testing instance 18
# --Fitness 0.873108
#
# testing instance 19
# --Fitness 0.861508
#
# testing instance 20
# --Fitness 0.863448
#
# testing instance 21
# --Fitness 0.868168
#
# testing instance 22
# --Fitness 0.863191
#
# testing instance 23
# --Fitness 0.872845
#
# testing instance 24
# --Fitness 0.873108
#
# testing instance 25
# --Fitness 0.873108
#
# testing instance 26
# --Fitness 0.873108
#
# testing instance 27
# --Fitness 0.861839
#
# testing instance 28
# --Fitness 0.873108
#
# testing instance 29
# --Fitness 0.873108
#
# testing instance 30
# --Fitness 0.858407
#
# testing instance 31
# --Fitness 0.861355
#
# testing instance 32
# --Fitness 0.873108
#
# testing instance 33
# --Fitness 0.873108
#
# testing instance 34
# --Fitness 0.865875
#
# testing instance 35
# --Fitness 0.870871
#
# testing instance 36
# --Fitness 0.873108
#
# testing instance 37
# --Fitness 0.873108
#
# testing instance 38
# --Fitness 0.873108
#
# testing instance 39
# --Fitness 0.873108
#
# testing instance 40
# --Fitness 0.868864
#
# testing instance 41
# --Fitness 0.866195
#
# testing instance 42
# --Fitness 0.864423
#
# testing instance 43
# --Fitness 0.873108
#
# testing instance 44
# --Fitness 0.873108
#
# testing instance 45
# --Fitness 0.867776
#
# testing instance 46
# --Fitness 0.873108
#
# testing instance 47
# --Fitness 0.873108
#
# testing instance 48
# --Fitness 0.863928
#
# testing instance 49
# --Fitness 0.863928
#
# Generation 94 Best fitness (5-fold mae cv): 0.873108
# Generation 95
#
# testing instance 5
# --Fitness 0.873108
#
# testing instance 6
# --Fitness 0.863420
#
# testing instance 7
# --Fitness 0.859774
#
# testing instance 8
# --Fitness 0.873108
#
# testing instance 9
# --Fitness 0.873108
#
# testing instance 10
# --Fitness 0.873108
#
# testing instance 11
# --Fitness 0.873108
#
# testing instance 12
# --Fitness 0.873108
#
# testing instance 13
# --Fitness 0.863569
#
# testing instance 14
# --Fitness 0.873108
#
# testing instance 15
# --Fitness 0.862565
#
# testing instance 16
# --Fitness 0.868870
#
# testing instance 17
# --Fitness 0.867776
#
# testing instance 18
# --Fitness 0.873108
#
# testing instance 19
# --Fitness 0.864587
#
# testing instance 20
# --Fitness 0.873108
#
# testing instance 21
# --Fitness 0.873108
#
# testing instance 22
# --Fitness 0.866273
#
# testing instance 23
# --Fitness 0.864361
#
# testing instance 24
# --Fitness 0.873108
#
# testing instance 25
# --Fitness 0.873108
#
# testing instance 26
# --Fitness 0.873108
#
# testing instance 27
# --Fitness 0.873108
#
# testing instance 28
# --Fitness 0.865078
#
# testing instance 29
# --Fitness 0.863928
#
# testing instance 30
# --Fitness 0.867595
#
# testing instance 31
# --Fitness 0.873108
#
# testing instance 32
# --Fitness 0.873108
#
# testing instance 33
# --Fitness 0.865435
#
# testing instance 34
# --Fitness 0.873108
#
# testing instance 35
# --Fitness 0.873108
#
# testing instance 36
# --Fitness 0.873108
#
# testing instance 37
# --Fitness 0.868732
#
# testing instance 38
# --Fitness 0.862276
#
# testing instance 39
# --Fitness 0.863928
#
# testing instance 40
# --Fitness 0.863928
#
# testing instance 41
# --Fitness 0.865141
#
# testing instance 42
# --Fitness 0.868243
#
# testing instance 43
# --Fitness 0.868770
#
# testing instance 44
# --Fitness 0.873108
#
# testing instance 45
# --Fitness 0.863764
#
# testing instance 46
# --Fitness 0.873108
#
# testing instance 47
# --Fitness 0.867007
#
# testing instance 48
# --Fitness 0.873108
#
# testing instance 49
# --Fitness 0.873108
#
# Generation 95 Best fitness (5-fold mae cv): 0.873108
# Generation 96
#
# testing instance 5
# --Fitness 0.873108
#
# testing instance 6
# --Fitness 0.873108
#
# testing instance 7
# --Fitness 0.873108
#
# testing instance 8
# --Fitness 0.866376
#
# testing instance 9
# --Fitness 0.873108
#
# testing instance 10
# --Fitness 0.873108
#
# testing instance 11
# --Fitness 0.873108
#
# testing instance 12
# --Fitness 0.859774
#
# testing instance 13
# --Fitness 0.873108
#
# testing instance 14
# --Fitness 0.867136
#
# testing instance 15
# --Fitness 0.864997
#
# testing instance 16
# --Fitness 0.873108
#
# testing instance 17
# --Fitness 0.873108
#
# testing instance 18
# --Fitness 0.861488
#
# testing instance 19
# --Fitness 0.873108
#
# testing instance 20
# --Fitness 0.867189
#
# testing instance 21
# --Fitness 0.873108
#
# testing instance 22
# --Fitness 0.873108
#
# testing instance 23
# --Fitness 0.867223
#
# testing instance 24
# --Fitness 0.865126
#
# testing instance 25
# --Fitness 0.864824
#
# testing instance 26
# --Fitness 0.873108
#
# testing instance 27
# --Fitness 0.873108
#
# testing instance 28
# --Fitness 0.865917
#
# testing instance 29
# --Fitness 0.873108
#
# testing instance 30
# --Fitness 0.862205
#
# testing instance 31
# --Fitness 0.873108
#
# testing instance 32
# --Fitness 0.873108
#
# testing instance 33
# --Fitness 0.865191
#
# testing instance 34
# --Fitness 0.873108
#
# testing instance 35
# --Fitness 0.865343
#
# testing instance 36
# --Fitness 0.869210
#
# testing instance 37
# --Fitness 0.864318
#
# testing instance 38
# --Fitness 0.873108
#
# testing instance 39
# --Fitness 0.873108
#
# testing instance 40
# --Fitness 0.859575
#
# testing instance 41
# --Fitness 0.873108
#
# testing instance 42
# --Fitness 0.873108
#
# testing instance 43
# --Fitness 0.861159
#
# testing instance 44
# --Fitness 0.873108
#
# testing instance 45
# --Fitness 0.863928
#
# testing instance 46
# --Fitness 0.873108
#
# testing instance 47
# --Fitness 0.859137
#
# testing instance 48
# --Fitness 0.873108
#
# testing instance 49
# --Fitness 0.868612
#
# Generation 96 Best fitness (5-fold mae cv): 0.873108
# Generation 97
#
# testing instance 5
# --Fitness 0.873108
#
# testing instance 6
# --Fitness 0.865792
#
# testing instance 7
# --Fitness 0.873108
#
# testing instance 8
# --Fitness 0.873108
#
# testing instance 9
# --Fitness 0.873108
#
# testing instance 10
# --Fitness 0.863528
#
# testing instance 11
# --Fitness 0.868500
#
# testing instance 12
# --Fitness 0.870871
#
# testing instance 13
# --Fitness 0.873108
#
# testing instance 14
# --Fitness 0.863928
#
# testing instance 15
# --Fitness 0.873108
#
# testing instance 16
# --Fitness 0.866332
#
# testing instance 17
# --Fitness 0.873108
#
# testing instance 18
# --Fitness 0.859774
#
# testing instance 19
# --Fitness 0.873108
#
# testing instance 20
# --Fitness 0.862860
#
# testing instance 21
# --Fitness 0.864482
#
# testing instance 22
# --Fitness 0.873108
#
# testing instance 23
# --Fitness 0.873108
#
# testing instance 24
# --Fitness 0.873108
#
# testing instance 25
# --Fitness 0.873108
#
# testing instance 26
# --Fitness 0.863928
#
# testing instance 27
# --Fitness 0.873108
#
# testing instance 28
# --Fitness 0.864263
#
# testing instance 29
# --Fitness 0.873108
#
# testing instance 30
# --Fitness 0.873108
#
# testing instance 31
# --Fitness 0.873108
#
# testing instance 32
# --Fitness 0.861488
#
# testing instance 33
# --Fitness 0.873108
#
# testing instance 34
# --Fitness 0.873108
#
# testing instance 35
# --Fitness 0.873108
#
# testing instance 36
# --Fitness 0.873108
#
# testing instance 37
# --Fitness 0.873108
#
# testing instance 38
# --Fitness 0.873108
#
# testing instance 39
# --Fitness 0.873108
#
# testing instance 40
# --Fitness 0.873108
#
# testing instance 41
# --Fitness 0.867934
#
# testing instance 42
# --Fitness 0.873108
#
# testing instance 43
# --Fitness 0.873108
#
# testing instance 44
# --Fitness 0.865665
#
# testing instance 45
# --Fitness 0.873108
#
# testing instance 46
# --Fitness 0.866474
#
# testing instance 47
# --Fitness 0.861292
#
# testing instance 48
# --Fitness 0.873108
#
# testing instance 49
# --Fitness 0.873108
#
# Generation 97 Best fitness (5-fold mae cv): 0.873108
# Generation 98
#
# testing instance 5
# --Fitness 0.861858
#
# testing instance 6
# --Fitness 0.873108
#
# testing instance 7
# --Fitness 0.867136
#
# testing instance 8
# --Fitness 0.864817
#
# testing instance 9
# --Fitness 0.873108
#
# testing instance 10
# --Fitness 0.873108
#
# testing instance 11
# --Fitness 0.873108
#
# testing instance 12
# --Fitness 0.873108
#
# testing instance 13
# --Fitness 0.867567
#
# testing instance 14
# --Fitness 0.873108
#
# testing instance 15
# --Fitness 0.873108
#
# testing instance 16
# --Fitness 0.873108
#
# testing instance 17
# --Fitness 0.873108
#
# testing instance 18
# --Fitness 0.873108
#
# testing instance 19
# --Fitness 0.867106
#
# testing instance 20
# --Fitness 0.866357
#
# testing instance 21
# --Fitness 0.858642
#
# testing instance 22
# --Fitness 0.873108
#
# testing instance 23
# --Fitness 0.873108
#
# testing instance 24
# --Fitness 0.865915
#
# testing instance 25
# --Fitness 0.873108
#
# testing instance 26
# --Fitness 0.866208
#
# testing instance 27
# --Fitness 0.861320
#
# testing instance 28
# --Fitness 0.857959
#
# testing instance 29
# --Fitness 0.861598
#
# testing instance 30
# --Fitness 0.870871
#
# testing instance 31
# --Fitness 0.864002
#
# testing instance 32
# --Fitness 0.863740
#
# testing instance 33
# --Fitness 0.873108
#
# testing instance 34
# --Fitness 0.873108
#
# testing instance 35
# --Fitness 0.863928
#
# testing instance 36
# --Fitness 0.868703
#
# testing instance 37
# --Fitness 0.873108
#
# testing instance 38
# --Fitness 0.866893
#
# testing instance 39
# --Fitness 0.873108
#
# testing instance 40
# --Fitness 0.861508
#
# testing instance 41
# --Fitness 0.873108
#
# testing instance 42
# --Fitness 0.865665
#
# testing instance 43
# --Fitness 0.863782
#
# testing instance 44
# --Fitness 0.873108
#
# testing instance 45
# --Fitness 0.860654
#
# testing instance 46
# --Fitness 0.859774
#
# testing instance 47
# --Fitness 0.873108
#
# testing instance 48
# --Fitness 0.867680
#
# testing instance 49
# --Fitness 0.873108
#
# Generation 98 Best fitness (5-fold mae cv): 0.873108
# Generation 99
#
# testing instance 5
# --Fitness 0.865158
#
# testing instance 6
# --Fitness 0.862496
#
# testing instance 7
# --Fitness 0.873108
#
# testing instance 8
# --Fitness 0.873108
#
# testing instance 9
# --Fitness 0.873108
#
# testing instance 10
# --Fitness 0.873108
#
# testing instance 11
# --Fitness 0.873108
#
# testing instance 12
# --Fitness 0.867136
#
# testing instance 13
# --Fitness 0.856470
#
# testing instance 14
# --Fitness 0.863463
#
# testing instance 15
# --Fitness 0.862860
#
# testing instance 16
# --Fitness 0.863928
#
# testing instance 17
# --Fitness 0.873108
#
# testing instance 18
# --Fitness 0.862607
#
# testing instance 19
# --Fitness 0.873108
#
# testing instance 20
# --Fitness 0.866328
#
# testing instance 21
# --Fitness 0.873108
#
# testing instance 22
# --Fitness 0.873108
#
# testing instance 23
# --Fitness 0.873108
#
# testing instance 24
# --Fitness 0.862856
#
# testing instance 25
# --Fitness 0.867567
#
# testing instance 26
# --Fitness 0.873108
#
# testing instance 27
# --Fitness 0.862019
#
# testing instance 28
# --Fitness 0.861508
#
# testing instance 29
# --Fitness 0.873108
#
# testing instance 30
# --Fitness 0.872845
#
# testing instance 31
# --Fitness 0.863483
#
# testing instance 32
# --Fitness 0.866630
#
# testing instance 33
# --Fitness 0.873108
#
# testing instance 34
# --Fitness 0.858791
#
# testing instance 35
# --Fitness 0.866382
#
# testing instance 36
# --Fitness 0.873108
#
# testing instance 37
# --Fitness 0.873108
#
# testing instance 38
# --Fitness 0.866414
#
# testing instance 39
# --Fitness 0.873108
#
# testing instance 40
# --Fitness 0.873108
#
# testing instance 41
# --Fitness 0.861995
#
# testing instance 42
# --Fitness 0.865389
#
# testing instance 43
# --Fitness 0.873108
#
# testing instance 44
# --Fitness 0.865482
#
# testing instance 45
# --Fitness 0.873108
#
# testing instance 46
# --Fitness 0.873108
#
# testing instance 47
# --Fitness 0.873108
#
# testing instance 48
# --Fitness 0.864742
#
# testing instance 49
# --Fitness 0.867457
#
# Generation 99 Best fitness (5-fold mae cv): 0.873108

# %%
param = {
    'objective':'binary:logitraw',
    'tree_method':'hist',
    
    "eta":0.427638,
    "max_depth":11,
    "subsample":0.834637,
    "colsample_bytree":0.849069,
    "min_child_weight":5,
    "max_bin":107
    
}
bst = xgb.train(param,dtrain,num_boost_round=200)
pred = bst.predict(dtest)
preds = []
for p in pred:
    if p <0:
        preds.append(0)
    else:
        preds.append(1)
print(accuracy_score(ytest,np.sign(preds)))
# Out:
# 0.844444444444

# %%
preds
# Out:
# []

# %%
ytest
# Out:
# 812    0
# 626    0
# 32     1
# 175    0
# 869    1
# 27     0
# 256    1
# 546    1
# 132    0
# 872    0
# 10     1
# 410    0
# 121    0
# 333    0
# 886    0
# 727    1
# 404    0
# 243    0
# 759    1
# 618    1
# 584    0
# 434    0
# 480    0
# 219    0
# 354    0
# 506    1
# 660    1
# 269    1
# 378    0
# 14     0
#       ..
# 398    0
# 110    0
# 11     1
# 442    0
# 663    0
# 53     1
# 373    0
# 142    1
# 262    0
# 63     0
# 52     1
# 88     1
# 334    1
# 623    0
# 322    1
# 49     0
# 413    0
# 655    0
# 430    1
# 564    0
# 427    1
# 718    0
# 33     0
# 78     1
# 425    0
# 852    0
# 271    1
# 871    1
# 733    0
# 312    0
# Name: Survived, Length: 90, dtype: int64
